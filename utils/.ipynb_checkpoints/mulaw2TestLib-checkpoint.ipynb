# %%
import numpy as np

# %%
#assume data is in [-1,1]
# Note: if you want mu2f(f2mu(0)==0, choose an odd number of descrete values (eg 255)  
class mulaw():
    def __init__(self, nvals):
        if nvals > 256 :
            raise ValueError('mulaw written to accommodate number of descrete value up to 256 only')
        self.nvals=nvals
        self.midpoint=(nvals-1.)/2.
        self.lognvals=np.log(nvals)
        #Brute force method to get the table of muvalues so we can index them with a one-hot vector
        #...just need enough numbers in linspace so we are sure to hit each muval at least once.
        #...12000 is adequate when the mutable length is 256, but goes up with 
        self.mutable=np.unique(self._decimate(self._float2mu(np.linspace(-1,1,num=12000, endpoint=False)))) 
        print("mutable is of length = " + str(len(self.mutable)))

    def _float2mu(self, data):
        y=[ np.sign(x)*( (np.log(1+(self.nvals-1)*abs(x)))/self.lognvals)  for x in data] #[-1,1] float
        return y

    def _decimate1 (self, m) : #assume m in [-1,1] - the epsilon is so we can accommodate []
        return np.round((self.midpoint-.000000001)*(m+1))/self.midpoint -1. 

    def _decimate(self, data) :
        return [self._decimate1(m) for m in data]

    # returns [-1,1] on linear scale
    def _mu2float(self, mdata) :
        d=1/(self.nvals-1)
        y=[ np.sign(x)*d*(np.power(self.nvals,np.abs(x))-1) for x in mdata ]
        return y

    def _onehot2mu1(self, m) :
        return self.mutable[np.argmax(m)]

    def _onehot2mu(self, a) :
        return [self._onehot2mu1(m) for m in a]

    def _mu2index(self, mval) :
        #This needs to be uint16 if you use ndvals > 256
        return np.uint8(round((self.nvals-1)*(1+ self._decimate1(mval))/2)) 

    def _mu2onehot1(self, m) :
        oh=np.zeros(self.nvals)
        oh[self._mu2index(m)]=1
        return oh

    def _mu2onehot(self, a) :
        return [self._mu2onehot1(x) for x in a]    
    
    # *******************  for export only   ****************
    def encode(self, a) :
        return self._mu2onehot(self._float2mu(a))
        
    def decode(self, oh) :
        return mlaw._mu2float(mlaw._onehot2mu(oh))

# %%
numdvals=15
mlaw= mulaw(numdvals)

#Testing ground

orig = np.linspace(-1, 1, num=11, endpoint=True)
print("orig = " + str(orig))
mu=mlaw._float2mu(orig)
print("mu = " + str(mu))
z=mlaw._decimate(mu)
print("z = " + str(z))
f=mlaw._mu2float(z)
print("f = " + str(f))

oh=np.zeros(numdvals)
oh[int(numdvals/2)-1]=1
om = mlaw._onehot2mu1(oh)
print("om = " + str(om))
 
idx=mlaw._mu2index(0)
print("idx = " + str(idx) + " (should be numdvals/2 -1) for even number of vals")
# Out:
# mutable is of length = 15
# orig = [-1.  -0.8 -0.6 -0.4 -0.2  0.   0.2  0.4  0.6  0.8  1. ]
# mu = [-1.0, -0.92370368567063321, -0.8274254621882422, -0.69683702623545118, -0.49297500695850394, 0.0, 0.49297500695850416, 0.69683702623545141, 0.8274254621882422, 0.92370368567063321, 1.0]
# z = [-1.0, -0.85714285714285721, -0.85714285714285721, -0.7142857142857143, -0.4285714285714286, 0.0, 0.4285714285714286, 0.71428571428571419, 0.85714285714285721, 0.85714285714285721, 1.0]
# f = [-1.0, -0.65626776146231958, -0.65626776146231958, -0.42281058461408894, -0.15655894904613898, 0.0, 0.15655894904613898, 0.42281058461408871, 0.65626776146231958, 0.65626776146231958, 1.0]
# om = -0.142857142857
# idx = 7 (should be numdvals/2 -1) for even number of vals

# %%
from numpy import *
import math
import matplotlib.pyplot as plt

t = linspace(0,2*math.pi,400)
a = sin(t)
# encode then decode
b = mlaw._mu2float(mlaw._decimate(mlaw._float2mu(a)))
# test one hot conversions  (the descretized b and c should look exactly the same)
c = mlaw._mu2float(mlaw._onehot2mu(mlaw._mu2onehot(mlaw._float2mu(a))))
# decimate mulaw
d = mlaw._float2mu(a)

plt.plot(t, a, t, b, t, c, t, d)
plt.show()

# %%
t = linspace(0,2*math.pi,400)
a = sin(t)
# encode 
oh = mlaw.encode(a)
print(str(shape(oh)))
c=mlaw.decode(oh)

plt.plot(t, a, t, c)
plt.show()
# Out:
# (400, 15)
